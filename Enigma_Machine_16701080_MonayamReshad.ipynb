# %%
def init():
  alphabets = []
  rotor1 = []
  rotor2 = []
  rotor3 = []
  
  alphabets[:0] = "abcdefghijklmnopqrstuvwxyz"
  rotor1[:0] = "dmtwsilruyqnkfejcazbpgxohv"
  rotor2[:0] = "hqzgpjtmoblncifdyawveusrkx"
  rotor3[:0] = "uqntlszfmrehdpxkibvygjcwoa"

  alphabets.clear()
  rotors.clear()


  reflector = {
      'a': 'y', 'b': 'r', 'c': 'u', 'd': 'h', 'e': 'q', 'f': 's','g': 'l', 
      'i': 'p', 'j': 'x', 'k': 'n', 'm': 'o', 't': 'z','v': 'w', 'y': 'a', 
      'r': 'b', 'u': 'c', 'h': 'd', 'q': 'e', 's': 'f', 'l': 'g', 'p': 'i', 
      'x': 'j', 'n': 'k', 'o': 'm', 'z': 't', 'w': 'v'
  }
  
  return alphabets, rotor1, rotor2, rotor3, reflector

def getSettings():
  settings = input("Insert 3 lowercase alphabets without any space: ")
  while len(settings) != 3 and settings.tolower() == False:
    settings = input("Error! Please follow the instruction and try again: ")

  return settings

def getIndexOfRotors(settings, rotor1, rotor2, rotor3):
  index1 = rotor1.index(settings[0])
  index2 = rotor2.index(settings[1])
  index3 = rotor2.index(settings[2])

  return index1, index2, index3

def setRotorInConfiguredPosition(rotor1, rotor2, rotor3, index1 = 0, index2 = 0, index3 = 0):
  rotor1 = rotor1[index1:] + rotor1[index1]
  rotor2 = rotor2[index2:] + rotor2[index2]
  rotor3 = rotor3[index3:] + rotor3[index3]
  

defMessage(message, alphabets, rotor1, rotor2, rotor3, reflector):
  index1 = 0
  index2 = 0
  index3 = 0

  out_message = ""

  for ch in message:
    if ch < 'a' or ch > 'z':
      out_message += ch
      continue
    
    newch1 = rotor1[alphabets.index(ch)]
    newch1 = rotor2[alphabets.index(newch1)]
    newch1 = rotor3[alphabets.index(newch1)]

    out_message += newch2

    index1 = (index1 + 1) % 26
    rotor1 = rotor1[1:] + rotor1[:1]

    if index1 == 0:
      index2 = (index2 + 1) % 26
      rotor2 = rotor2[1:] + rotor2[:1]

      if index2 == 0:
        index3 = (index3 + 1) % 26
        rotor3 = rotor3[1:] + rotor3[:1]
    
    return out_message
